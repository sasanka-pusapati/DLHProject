# %%
import pandas as pd
import os
import numpy as np
from gensim.models import Word2Vec, FastText
#sasanka2@illinois.edu - commented out unused imports
#import glove
#from glove import Corpus

import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, Activation, Concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D

from keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau
from keras.utils import np_utils
#from keras.backend.tensorflow_backend import set_session, clear_session, get_session
from keras.backend import set_session, clear_session, get_session
import tensorflow as tf


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-05-07 22:56:39.933469: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("data/"+type_of_ner+"_x_train.pkl")
x_dev_lstm = pd.read_pickle("data/"+type_of_ner+"_x_dev.pkl")
x_test_lstm = pd.read_pickle("data/"+type_of_ner+"_x_test.pkl")

y_train = pd.read_pickle("data/"+type_of_ner+"_y_train.pkl")
y_dev = pd.read_pickle("data/"+type_of_ner+"_y_dev.pkl")
y_test = pd.read_pickle("data/"+type_of_ner+"_y_test.pkl")


ner_word2vec = pd.read_pickle("data/"+type_of_ner+"_ner_word2vec_limited_dict.pkl")
ner_fasttext = pd.read_pickle("data/"+type_of_ner+"_ner_fasttext_limited_dict.pkl")
ner_concat = pd.read_pickle("data/"+type_of_ner+"_ner_combined_limited_dict.pkl")

train_ids = pd.read_pickle("data/"+type_of_ner+"_train_ids.pkl")
dev_ids = pd.read_pickle("data/"+type_of_ner+"_dev_ids.pkl")
test_ids = pd.read_pickle("data/"+type_of_ner+"_test_ids.pkl")

# %%
def make_prediction_cnn(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_cnn(predictions, probs, ground_truth, 
                          
                          embed_name, problem_type, iteration, hidden_unit_size,
                          
                          sequence_name, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

    result_path = "results/cnn/"
    file_name = str(sequence_name)+"-"+str(hidden_unit_size)+"-"+embed_name
    file_name = file_name +"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+"-cnn-.p"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)
    
def print_scores_cnn(predictions, probs, ground_truth, model_name, problem_type, iteration, hidden_unit_size):
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    print ("AUC: ", auc, "AUPRC: ", auprc, "F1: ", F1)
    
def get_subvector_data(size, embed_name, data):
    if embed_name == "concat":
        vector_size = 200
    else:
        vector_size = 100

    x_data = {}
    for k, v in data.items():
        number_of_additional_vector = len(v) - size
        vector = []
        for i in v:
            vector.append(i)
        if number_of_additional_vector < 0: 
            number_of_additional_vector = np.abs(number_of_additional_vector)

            temp = vector[:size]
            for i in range(0, number_of_additional_vector):
                temp.append(np.zeros(vector_size))
            x_data[k] = np.asarray(temp)
        else:
            x_data[k] = np.asarray(vector[:size])

    return x_data


def proposedmodel(layer_name, number_of_unit, embedding_name, ner_limit, num_filter):
    if embedding_name == "concat":
        input_dimension = 200
    else:
        input_dimension = 100

    sequence_input = Input(shape=(24,104))

    input_img = Input(shape=(ner_limit, input_dimension), name = "cnn_input")

    convs = []
    filter_sizes = [2,3,4]



    #text_conv1d = Conv1D(filters=num_filter, kernel_size=3,
    #             padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
    #                     kernel_initializer=tf.contrib.layers.xavier_initializer() )(input_img)
    
    #text_conv1d = Conv1D(filters=num_filter*2, kernel_size=3,
    #             padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
    #                    kernel_initializer=tf.contrib.layers.xavier_initializer())(text_conv1d)
    
    #text_conv1d = Conv1D(filters=num_filter*3, kernel_size=3,
    #             padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
    #                    kernel_initializer=tf.contrib.layers.xavier_initializer())(text_conv1d)

    text_conv1d = Conv1D(filters=num_filter, kernel_size=3,
                     padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                     kernel_initializer=tf.keras.initializers.glorot_normal() )(input_img)

    text_conv1d = Conv1D(filters=num_filter*2, kernel_size=3,
                     padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                     kernel_initializer=tf.keras.initializers.glorot_normal())(text_conv1d)

    text_conv1d = Conv1D(filters=num_filter*3, kernel_size=3,
                     padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                     kernel_initializer=tf.keras.initializers.glorot_normal())(text_conv1d)

    #concat_conv = keras.layers.Concatenate()([text_conv1d, text_conv1d_2, text_conv1d_3])
    text_embeddings = GlobalMaxPooling1D()(text_conv1d)
    #text_embeddings = Dense(128, activation="relu")(text_embeddings)
    
    if layer_name == "GRU":
        x = GRU(number_of_unit)(sequence_input)
    elif layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)

    concatenated = keras.layers.Concatenate()([x, text_embeddings])
    #concatenated = merge([x, text_embeddings], mode='concat', concat_axis=1)

    concatenated = Dense(512, activation='relu')(concatenated)
    concatenated = Dropout(0.2)(concatenated)
    #concatenated = Dense(256, activation='relu')(concatenated)
    #concatenated = Dense(512, activation='relu')(concatenated)
    
    #concatenated = Dense(512, activation='relu')(concatenated)
    #logits_regularizer = tf.contrib.layers.l2_regularizer(scale=0.01)
    logits_regularizer = tf.keras.regularizers.L2(0.01)

    #preds = Dense(1, activation='sigmoid',use_bias=False,
    #                     kernel_initializer=tf.contrib.layers.xavier_initializer(),
    #              kernel_regularizer=logits_regularizer)(concatenated)
    preds = Dense(1, activation='sigmoid',use_bias=False,
                  kernel_initializer=tf.keras.initializers.glorot_normal(),
                  kernel_regularizer=logits_regularizer)(concatenated)
    
    
    #opt = Adam(lr=1e-4, decay = 0.01)
    
    opt = Adam(lr=1e-3, decay = 0.01)
    
    #opt = Adam(lr=0.001)

    model = Model(inputs=[sequence_input, input_img], outputs=preds)
    model.compile(loss='binary_crossentropy',
                  optimizer=opt,
                  metrics=['acc'])
    
    return model

# %%
embedding_types = ['word2vec', 'fasttext'] #, 'concat']
embedding_dict = [ner_word2vec, ner_fasttext] #, ner_concat]

target_problems = ['mort_hosp', 'mort_icu'] #, 'los_3', 'los_7']

num_epoch = 100
model_patience = 5
monitor_criteria = 'val_loss'
#monitor_criteria = 'val_acc'
batch_size = 64

filter_number = 32
ner_representation_limit = 64
activation_func = "relu"

sequence_model = "GRU"
sequence_hidden_unit = 256

maxiter = 11
for embed_dict, embed_name in zip(embedding_dict, embedding_types):    
    print ("Embedding: ", embed_name)
    print("=============================")
    
    temp_train_ner = dict((k, embed_dict[k]) for k in train_ids)
    tem_dev_ner = dict((k, embed_dict[k]) for k in dev_ids)
    temp_test_ner = dict((k, embed_dict[k]) for k in test_ids)

    x_train_dict = {}
    x_dev_dict = {}
    x_test_dict = {}

    x_train_dict = get_subvector_data(ner_representation_limit, embed_name, temp_train_ner)
    x_dev_dict = get_subvector_data(ner_representation_limit, embed_name, tem_dev_ner)
    x_test_dict = get_subvector_data(ner_representation_limit, embed_name, temp_test_ner)

    x_train_dict_sorted = collections.OrderedDict(sorted(x_train_dict.items()))
    x_dev_dict_sorted = collections.OrderedDict(sorted(x_dev_dict.items()))
    x_test_dict_sorted = collections.OrderedDict(sorted(x_test_dict.items()))

    #x_train_ner = np.asarray(x_train_dict_sorted.values())
    #x_dev_ner = np.asarray(x_dev_dict_sorted.values())
    #x_test_ner = np.asarray(x_test_dict_sorted.values())

    list_train_ner =[]
    list_test_ner =[]
    list_dev_ner =[]
    for k,v in x_train_dict_sorted.items():
        list_train_ner.append(v)
    for k,v in x_test_dict_sorted.items():
        list_test_ner.append(v)
    for k,v in x_dev_dict_sorted.items():
        list_dev_ner.append(v)



    x_train_ner = np.array(list_train_ner)
    x_dev_ner = np.array(list_dev_ner)
    x_test_ner = np.array(list_test_ner)
        
    for iteration in range(1,maxiter):
        print ("Iteration number: ", iteration)
    
        for each_problem in target_problems:
            print ("Problem type: ", each_problem)
            print ("__________________")
            
            
            early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
            
            best_model_name = str(ner_representation_limit)+"-basiccnn1d-"+str(embed_name)+"-"+str(each_problem)+"-"+"best_model.hdf5"
            
            checkpoint = ModelCheckpoint(best_model_name, monitor=monitor_criteria, verbose=1,
                save_best_only=True, mode='min')
            
            reduce_lr = ReduceLROnPlateau(monitor=monitor_criteria, factor=0.2,
                              patience=2, min_lr=0.00001, epsilon=1e-4, mode='min')
            

            callbacks = [early_stopping_monitor, checkpoint, reduce_lr]
            
            #model = textCNN(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit)
            model = proposedmodel(sequence_model, sequence_hidden_unit, 
                               embed_name, ner_representation_limit,filter_number)
            model.fit([x_train_lstm, x_train_ner], y_train[each_problem], epochs=num_epoch, verbose=1, 
                      validation_data=([x_dev_lstm, x_dev_ner], y_dev[each_problem]), callbacks=callbacks, batch_size=batch_size)
            
            
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            print_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration, sequence_hidden_unit)
            
            model.load_weights(best_model_name)
                      
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            save_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration,
                            sequence_hidden_unit, sequence_model, type_of_ner)
            del model
            clear_session()
            gc.collect()
# Out:
# Embedding:  word2vec
# =============================
# Iteration number:  1
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# 2023-05-07 22:57:09.926246: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2839 - acc: 0.9032
# Epoch 1: val_loss improved from inf to 0.25502, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 15s 59ms/step - loss: 0.2835 - acc: 0.9033 - val_loss: 0.2550 - val_acc: 0.9119 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2350 - acc: 0.9169
# Epoch 2: val_loss improved from 0.25502 to 0.24838, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 58ms/step - loss: 0.2350 - acc: 0.9169 - val_loss: 0.2484 - val_acc: 0.9142 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2183 - acc: 0.9231
# Epoch 3: val_loss did not improve from 0.24838
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2181 - acc: 0.9233 - val_loss: 0.2543 - val_acc: 0.9048 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2069 - acc: 0.9267
# Epoch 4: val_loss did not improve from 0.24838
# 233/233 [==============================] - 14s 59ms/step - loss: 0.2071 - acc: 0.9265 - val_loss: 0.2489 - val_acc: 0.9100 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1954 - acc: 0.9301
# Epoch 5: val_loss improved from 0.24838 to 0.24833, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1952 - acc: 0.9301 - val_loss: 0.2483 - val_acc: 0.9095 - lr: 2.0000e-04
# Epoch 6/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1920 - acc: 0.9314
# Epoch 6: val_loss did not improve from 0.24833
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1922 - acc: 0.9313 - val_loss: 0.2486 - val_acc: 0.9100 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1902 - acc: 0.9321
# Epoch 7: val_loss did not improve from 0.24833
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1902 - acc: 0.9321 - val_loss: 0.2485 - val_acc: 0.9105 - lr: 4.0000e-05
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1895 - acc: 0.9317
# Epoch 8: val_loss did not improve from 0.24833
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1894 - acc: 0.9317 - val_loss: 0.2485 - val_acc: 0.9105 - lr: 4.0000e-05
# Epoch 9/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1898 - acc: 0.9329
# Epoch 9: val_loss did not improve from 0.24833
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1896 - acc: 0.9330 - val_loss: 0.2485 - val_acc: 0.9105 - lr: 1.0000e-05
# Epoch 10/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1891 - acc: 0.9331
# Epoch 10: val_loss did not improve from 0.24833
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1891 - acc: 0.9331 - val_loss: 0.2486 - val_acc: 0.9105 - lr: 1.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8812677806528953 AUPRC:  0.5851723845193826 F1:  0.482962962962963
# 133/133 [==============================] - 1s 9ms/step
# 0.8815011037527594 0.5874351526059534 0.9157994323557237 0.47492625368731556
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2132 - acc: 0.9361
# Epoch 1: val_loss improved from inf to 0.17131, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 15s 59ms/step - loss: 0.2132 - acc: 0.9361 - val_loss: 0.1713 - val_acc: 0.9425 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1707 - acc: 0.9442
# Epoch 2: val_loss improved from 0.17131 to 0.16982, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 14s 62ms/step - loss: 0.1710 - acc: 0.9439 - val_loss: 0.1698 - val_acc: 0.9439 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1560 - acc: 0.9466
# Epoch 3: val_loss improved from 0.16982 to 0.16924, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 14s 59ms/step - loss: 0.1563 - acc: 0.9466 - val_loss: 0.1692 - val_acc: 0.9430 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1460 - acc: 0.9495
# Epoch 4: val_loss did not improve from 0.16924
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1459 - acc: 0.9495 - val_loss: 0.1730 - val_acc: 0.9416 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1366 - acc: 0.9525
# Epoch 5: val_loss did not improve from 0.16924
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1365 - acc: 0.9525 - val_loss: 0.1728 - val_acc: 0.9444 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1271 - acc: 0.9556
# Epoch 6: val_loss did not improve from 0.16924
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1271 - acc: 0.9556 - val_loss: 0.1718 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1244 - acc: 0.9565
# Epoch 7: val_loss did not improve from 0.16924
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1245 - acc: 0.9564 - val_loss: 0.1725 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1235 - acc: 0.9562
# Epoch 8: val_loss did not improve from 0.16924
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1234 - acc: 0.9562 - val_loss: 0.1726 - val_acc: 0.9434 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 9ms/step
# AUC:  0.8883222845486997 AUPRC:  0.5271340353961942 F1:  0.4672489082969432
# 133/133 [==============================] - 1s 11ms/step
# 0.8853863575006748 0.5253621752084227 0.9437086092715232 0.449074074074074
# Iteration number:  2
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2879 - acc: 0.9037
# Epoch 1: val_loss improved from inf to 0.24770, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 15s 58ms/step - loss: 0.2875 - acc: 0.9039 - val_loss: 0.2477 - val_acc: 0.9123 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2348 - acc: 0.9156
# Epoch 2: val_loss improved from 0.24770 to 0.24724, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2348 - acc: 0.9156 - val_loss: 0.2472 - val_acc: 0.9133 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2191 - acc: 0.9214
# Epoch 3: val_loss improved from 0.24724 to 0.24441, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 56ms/step - loss: 0.2198 - acc: 0.9211 - val_loss: 0.2444 - val_acc: 0.9161 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2078 - acc: 0.9256
# Epoch 4: val_loss did not improve from 0.24441
# 233/233 [==============================] - 13s 56ms/step - loss: 0.2077 - acc: 0.9257 - val_loss: 0.2474 - val_acc: 0.9105 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1988 - acc: 0.9296
# Epoch 5: val_loss did not improve from 0.24441
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1988 - acc: 0.9296 - val_loss: 0.2469 - val_acc: 0.9142 - lr: 0.0010
# Epoch 6/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1884 - acc: 0.9319
# Epoch 6: val_loss did not improve from 0.24441
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1883 - acc: 0.9319 - val_loss: 0.2469 - val_acc: 0.9128 - lr: 2.0000e-04
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1857 - acc: 0.9330
# Epoch 7: val_loss did not improve from 0.24441
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1858 - acc: 0.9331 - val_loss: 0.2471 - val_acc: 0.9142 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1839 - acc: 0.9334
# Epoch 8: val_loss did not improve from 0.24441
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1838 - acc: 0.9335 - val_loss: 0.2471 - val_acc: 0.9142 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8789807464584887 AUPRC:  0.5805993516119502 F1:  0.4688427299703264
# 133/133 [==============================] - 1s 10ms/step
# 0.8776129701913659 0.5789900645438764 0.9157994323557237 0.4313099041533547
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2166 - acc: 0.9349
# Epoch 1: val_loss improved from inf to 0.18095, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 16s 60ms/step - loss: 0.2161 - acc: 0.9351 - val_loss: 0.1809 - val_acc: 0.9416 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1741 - acc: 0.9437
# Epoch 2: val_loss improved from 0.18095 to 0.17331, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1742 - acc: 0.9436 - val_loss: 0.1733 - val_acc: 0.9477 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1564 - acc: 0.9468
# Epoch 3: val_loss did not improve from 0.17331
# 233/233 [==============================] - 14s 58ms/step - loss: 0.1566 - acc: 0.9466 - val_loss: 0.1773 - val_acc: 0.9378 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1461 - acc: 0.9496
# Epoch 4: val_loss improved from 0.17331 to 0.17314, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1462 - acc: 0.9495 - val_loss: 0.1731 - val_acc: 0.9387 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1367 - acc: 0.9537
# Epoch 5: val_loss improved from 0.17314 to 0.17183, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1366 - acc: 0.9537 - val_loss: 0.1718 - val_acc: 0.9425 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1282 - acc: 0.9562
# Epoch 6: val_loss did not improve from 0.17183
# 233/233 [==============================] - 14s 59ms/step - loss: 0.1282 - acc: 0.9562 - val_loss: 0.1739 - val_acc: 0.9406 - lr: 0.0010
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1195 - acc: 0.9592
# Epoch 7: val_loss did not improve from 0.17183
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1196 - acc: 0.9591 - val_loss: 0.1760 - val_acc: 0.9411 - lr: 0.0010
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1115 - acc: 0.9622
# Epoch 8: val_loss did not improve from 0.17183
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1114 - acc: 0.9623 - val_loss: 0.1769 - val_acc: 0.9420 - lr: 2.0000e-04
# Epoch 9/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1093 - acc: 0.9631
# Epoch 9: val_loss did not improve from 0.17183
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1092 - acc: 0.9630 - val_loss: 0.1773 - val_acc: 0.9397 - lr: 2.0000e-04
# Epoch 10/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1076 - acc: 0.9644
# Epoch 10: val_loss did not improve from 0.17183
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1077 - acc: 0.9642 - val_loss: 0.1774 - val_acc: 0.9397 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8816855145933947 AUPRC:  0.520178640327679 F1:  0.4787472035794183
# 133/133 [==============================] - 1s 10ms/step
# 0.8844635423436755 0.518004138365622 0.9439451277199622 0.4601366742596812
# Iteration number:  3
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2846 - acc: 0.9002
# Epoch 1: val_loss improved from inf to 0.25094, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 15s 58ms/step - loss: 0.2845 - acc: 0.9002 - val_loss: 0.2509 - val_acc: 0.9166 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2352 - acc: 0.9172
# Epoch 2: val_loss improved from 0.25094 to 0.24596, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2354 - acc: 0.9170 - val_loss: 0.2460 - val_acc: 0.9105 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2188 - acc: 0.9211
# Epoch 3: val_loss did not improve from 0.24596
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2189 - acc: 0.9210 - val_loss: 0.2466 - val_acc: 0.9081 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2056 - acc: 0.9266
# Epoch 4: val_loss did not improve from 0.24596
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2053 - acc: 0.9267 - val_loss: 0.2483 - val_acc: 0.9109 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1945 - acc: 0.9303
# Epoch 5: val_loss improved from 0.24596 to 0.24457, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 14s 58ms/step - loss: 0.1944 - acc: 0.9303 - val_loss: 0.2446 - val_acc: 0.9114 - lr: 2.0000e-04
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1914 - acc: 0.9309
# Epoch 6: val_loss improved from 0.24457 to 0.24395, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1914 - acc: 0.9309 - val_loss: 0.2440 - val_acc: 0.9119 - lr: 2.0000e-04
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1895 - acc: 0.9317
# Epoch 7: val_loss did not improve from 0.24395
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1896 - acc: 0.9316 - val_loss: 0.2445 - val_acc: 0.9114 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1878 - acc: 0.9318
# Epoch 8: val_loss did not improve from 0.24395
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1878 - acc: 0.9319 - val_loss: 0.2448 - val_acc: 0.9114 - lr: 2.0000e-04
# Epoch 9/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1861 - acc: 0.9327
# Epoch 9: val_loss did not improve from 0.24395
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1860 - acc: 0.9327 - val_loss: 0.2448 - val_acc: 0.9119 - lr: 4.0000e-05
# Epoch 10/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1855 - acc: 0.9333
# Epoch 10: val_loss did not improve from 0.24395
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1855 - acc: 0.9333 - val_loss: 0.2448 - val_acc: 0.9119 - lr: 4.0000e-05
# Epoch 11/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1857 - acc: 0.9329
# Epoch 11: val_loss did not improve from 0.24395
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1854 - acc: 0.9330 - val_loss: 0.2448 - val_acc: 0.9119 - lr: 1.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8842503983743403 AUPRC:  0.5910249301489194 F1:  0.4761904761904762
# 133/133 [==============================] - 1s 10ms/step
# 0.8844945397131705 0.5912744009752712 0.9169820245979187 0.47690014903129657
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2175 - acc: 0.9337
# Epoch 1: val_loss improved from inf to 0.17852, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 15s 57ms/step - loss: 0.2176 - acc: 0.9337 - val_loss: 0.1785 - val_acc: 0.9411 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1726 - acc: 0.9428
# Epoch 2: val_loss improved from 0.17852 to 0.17325, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1735 - acc: 0.9426 - val_loss: 0.1733 - val_acc: 0.9434 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1596 - acc: 0.9457
# Epoch 3: val_loss did not improve from 0.17325
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1596 - acc: 0.9458 - val_loss: 0.1741 - val_acc: 0.9434 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1501 - acc: 0.9498
# Epoch 4: val_loss improved from 0.17325 to 0.17031, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1501 - acc: 0.9497 - val_loss: 0.1703 - val_acc: 0.9430 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1428 - acc: 0.9515
# Epoch 5: val_loss did not improve from 0.17031
# 233/233 [==============================] - 14s 58ms/step - loss: 0.1428 - acc: 0.9515 - val_loss: 0.1723 - val_acc: 0.9397 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1359 - acc: 0.9537
# Epoch 6: val_loss did not improve from 0.17031
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1359 - acc: 0.9537 - val_loss: 0.1729 - val_acc: 0.9420 - lr: 0.0010
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1291 - acc: 0.9549
# Epoch 7: val_loss did not improve from 0.17031
# 233/233 [==============================] - 14s 58ms/step - loss: 0.1292 - acc: 0.9548 - val_loss: 0.1723 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1271 - acc: 0.9562
# Epoch 8: val_loss did not improve from 0.17031
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1269 - acc: 0.9562 - val_loss: 0.1728 - val_acc: 0.9420 - lr: 2.0000e-04
# Epoch 9/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1258 - acc: 0.9562
# Epoch 9: val_loss did not improve from 0.17031
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1255 - acc: 0.9563 - val_loss: 0.1728 - val_acc: 0.9430 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8829212120000134 AUPRC:  0.5230281453323625 F1:  0.46799116997792495
# 133/133 [==============================] - 1s 11ms/step
# 0.8817471744774741 0.5168976842511577 0.9429990539262062 0.44851258581235703
# Iteration number:  4
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2892 - acc: 0.9028
# Epoch 1: val_loss improved from inf to 0.25013, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 15s 58ms/step - loss: 0.2890 - acc: 0.9029 - val_loss: 0.2501 - val_acc: 0.9133 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2365 - acc: 0.9160
# Epoch 2: val_loss improved from 0.25013 to 0.24892, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 14s 59ms/step - loss: 0.2365 - acc: 0.9160 - val_loss: 0.2489 - val_acc: 0.9119 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2200 - acc: 0.9204
# Epoch 3: val_loss improved from 0.24892 to 0.24660, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 14s 59ms/step - loss: 0.2198 - acc: 0.9205 - val_loss: 0.2466 - val_acc: 0.9119 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2091 - acc: 0.9238
# Epoch 4: val_loss improved from 0.24660 to 0.24379, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 57ms/step - loss: 0.2089 - acc: 0.9239 - val_loss: 0.2438 - val_acc: 0.9123 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1994 - acc: 0.9274
# Epoch 5: val_loss did not improve from 0.24379
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1994 - acc: 0.9274 - val_loss: 0.2484 - val_acc: 0.9100 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1909 - acc: 0.9306
# Epoch 6: val_loss did not improve from 0.24379
# 233/233 [==============================] - 14s 62ms/step - loss: 0.1909 - acc: 0.9306 - val_loss: 0.2455 - val_acc: 0.9142 - lr: 0.0010
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1814 - acc: 0.9341
# Epoch 7: val_loss did not improve from 0.24379
# 233/233 [==============================] - 14s 61ms/step - loss: 0.1814 - acc: 0.9341 - val_loss: 0.2469 - val_acc: 0.9142 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1798 - acc: 0.9342
# Epoch 8: val_loss did not improve from 0.24379
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1799 - acc: 0.9341 - val_loss: 0.2478 - val_acc: 0.9138 - lr: 2.0000e-04
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1786 - acc: 0.9348
# Epoch 9: val_loss did not improve from 0.24379
# 233/233 [==============================] - 14s 62ms/step - loss: 0.1786 - acc: 0.9348 - val_loss: 0.2479 - val_acc: 0.9142 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 11ms/step
# AUC:  0.8817157142230603 AUPRC:  0.5911440883172655 F1:  0.49062049062049057
# 133/133 [==============================] - 1s 11ms/step
# 0.8819309094630352 0.5945594914303342 0.9181646168401135 0.47416413373860183
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2155 - acc: 0.9334
# Epoch 1: val_loss improved from inf to 0.18361, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 15s 57ms/step - loss: 0.2155 - acc: 0.9334 - val_loss: 0.1836 - val_acc: 0.9406 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1734 - acc: 0.9432
# Epoch 2: val_loss improved from 0.18361 to 0.17295, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1733 - acc: 0.9432 - val_loss: 0.1729 - val_acc: 0.9430 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1592 - acc: 0.9465
# Epoch 3: val_loss improved from 0.17295 to 0.17215, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 55ms/step - loss: 0.1590 - acc: 0.9466 - val_loss: 0.1722 - val_acc: 0.9430 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1486 - acc: 0.9486
# Epoch 4: val_loss did not improve from 0.17215
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1483 - acc: 0.9488 - val_loss: 0.1723 - val_acc: 0.9420 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1400 - acc: 0.9513
# Epoch 5: val_loss did not improve from 0.17215
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1400 - acc: 0.9513 - val_loss: 0.1754 - val_acc: 0.9406 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1316 - acc: 0.9545
# Epoch 6: val_loss did not improve from 0.17215
# 233/233 [==============================] - 14s 61ms/step - loss: 0.1316 - acc: 0.9545 - val_loss: 0.1732 - val_acc: 0.9420 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1293 - acc: 0.9546
# Epoch 7: val_loss did not improve from 0.17215
# 233/233 [==============================] - 14s 60ms/step - loss: 0.1293 - acc: 0.9546 - val_loss: 0.1735 - val_acc: 0.9430 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1284 - acc: 0.9560
# Epoch 8: val_loss did not improve from 0.17215
# 233/233 [==============================] - 13s 58ms/step - loss: 0.1282 - acc: 0.9561 - val_loss: 0.1736 - val_acc: 0.9430 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8864958187932661 AUPRC:  0.5325752019556806 F1:  0.46153846153846145
# 133/133 [==============================] - 1s 11ms/step
# 0.8836402995670476 0.5319148285773588 0.9441816461684012 0.45370370370370366
# Iteration number:  5
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2912 - acc: 0.9009
# Epoch 1: val_loss improved from inf to 0.25082, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 15s 55ms/step - loss: 0.2911 - acc: 0.9008 - val_loss: 0.2508 - val_acc: 0.9156 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2389 - acc: 0.9164
# Epoch 2: val_loss improved from 0.25082 to 0.24964, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 55ms/step - loss: 0.2391 - acc: 0.9163 - val_loss: 0.2496 - val_acc: 0.9138 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2228 - acc: 0.9205
# Epoch 3: val_loss improved from 0.24964 to 0.24503, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 12s 54ms/step - loss: 0.2228 - acc: 0.9207 - val_loss: 0.2450 - val_acc: 0.9119 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2106 - acc: 0.9244
# Epoch 4: val_loss improved from 0.24503 to 0.23988, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 13s 54ms/step - loss: 0.2107 - acc: 0.9243 - val_loss: 0.2399 - val_acc: 0.9152 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.2016 - acc: 0.9269
# Epoch 5: val_loss did not improve from 0.23988
# 233/233 [==============================] - 13s 55ms/step - loss: 0.2016 - acc: 0.9268 - val_loss: 0.2439 - val_acc: 0.9156 - lr: 0.0010
# Epoch 6/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1931 - acc: 0.9306
# Epoch 6: val_loss did not improve from 0.23988
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1932 - acc: 0.9305 - val_loss: 0.2417 - val_acc: 0.9105 - lr: 0.0010
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1827 - acc: 0.9341
# Epoch 7: val_loss did not improve from 0.23988
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1832 - acc: 0.9339 - val_loss: 0.2419 - val_acc: 0.9133 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1816 - acc: 0.9341
# Epoch 8: val_loss did not improve from 0.23988
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1815 - acc: 0.9341 - val_loss: 0.2422 - val_acc: 0.9138 - lr: 2.0000e-04
# Epoch 9/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1802 - acc: 0.9339
# Epoch 9: val_loss did not improve from 0.23988
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1800 - acc: 0.9341 - val_loss: 0.2423 - val_acc: 0.9138 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 10ms/step
# AUC:  0.8810473224858558 AUPRC:  0.5916491293026078 F1:  0.4747774480712166
# 133/133 [==============================] - 1s 10ms/step
# 0.8776737862374457 0.5841148472165855 0.9169820245979187 0.45070422535211263
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2159 - acc: 0.9353
# Epoch 1: val_loss improved from inf to 0.17709, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 14s 54ms/step - loss: 0.2159 - acc: 0.9353 - val_loss: 0.1771 - val_acc: 0.9425 - lr: 0.0010
# Epoch 2/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1718 - acc: 0.9444
# Epoch 2: val_loss improved from 0.17709 to 0.17498, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 54ms/step - loss: 0.1717 - acc: 0.9444 - val_loss: 0.1750 - val_acc: 0.9425 - lr: 0.0010
# Epoch 3/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1580 - acc: 0.9479
# Epoch 3: val_loss did not improve from 0.17498
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1579 - acc: 0.9480 - val_loss: 0.1755 - val_acc: 0.9369 - lr: 0.0010
# Epoch 4/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1483 - acc: 0.9491
# Epoch 4: val_loss improved from 0.17498 to 0.17185, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1483 - acc: 0.9491 - val_loss: 0.1719 - val_acc: 0.9444 - lr: 0.0010
# Epoch 5/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1401 - acc: 0.9512
# Epoch 5: val_loss did not improve from 0.17185
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1401 - acc: 0.9512 - val_loss: 0.1722 - val_acc: 0.9439 - lr: 0.0010
# Epoch 6/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1316 - acc: 0.9541
# Epoch 6: val_loss did not improve from 0.17185
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1319 - acc: 0.9540 - val_loss: 0.1729 - val_acc: 0.9387 - lr: 0.0010
# Epoch 7/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1225 - acc: 0.9564
# Epoch 7: val_loss did not improve from 0.17185
# 233/233 [==============================] - 13s 57ms/step - loss: 0.1226 - acc: 0.9564 - val_loss: 0.1730 - val_acc: 0.9402 - lr: 2.0000e-04
# Epoch 8/100
# 232/233 [============================>.] - ETA: 0s - loss: 0.1214 - acc: 0.9573
# Epoch 8: val_loss did not improve from 0.17185
# 233/233 [==============================] - 13s 56ms/step - loss: 0.1213 - acc: 0.9573 - val_loss: 0.1734 - val_acc: 0.9402 - lr: 2.0000e-04
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1195 - acc: 0.9573
# Epoch 9: val_loss did not improve from 0.17185
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1195 - acc: 0.9573 - val_loss: 0.1734 - val_acc: 0.9402 - lr: 4.0000e-05
# 133/133 [==============================] - 3s 16ms/step
# AUC:  0.8866782987204741 AUPRC:  0.5193407263626378 F1:  0.46420824295010843
# 133/133 [==============================] - 2s 16ms/step
# 0.8871882426266444 0.5178137573721319 0.9427625354777672 0.4398148148148148
# Iteration number:  6
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2835 - acc: 0.9033
# Epoch 1: val_loss improved from inf to 0.24909, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 23s 90ms/step - loss: 0.2835 - acc: 0.9033 - val_loss: 0.2491 - val_acc: 0.9086 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2341 - acc: 0.9171
# Epoch 2: val_loss improved from 0.24909 to 0.24361, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 91ms/step - loss: 0.2341 - acc: 0.9171 - val_loss: 0.2436 - val_acc: 0.9133 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2178 - acc: 0.9212
# Epoch 3: val_loss improved from 0.24361 to 0.24284, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 91ms/step - loss: 0.2178 - acc: 0.9212 - val_loss: 0.2428 - val_acc: 0.9100 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2071 - acc: 0.9250
# Epoch 4: val_loss improved from 0.24284 to 0.24255, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 92ms/step - loss: 0.2071 - acc: 0.9250 - val_loss: 0.2425 - val_acc: 0.9123 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1970 - acc: 0.9280
# Epoch 5: val_loss improved from 0.24255 to 0.24195, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1970 - acc: 0.9280 - val_loss: 0.2419 - val_acc: 0.9175 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1870 - acc: 0.9315
# Epoch 6: val_loss did not improve from 0.24195
# 233/233 [==============================] - 22s 94ms/step - loss: 0.1870 - acc: 0.9315 - val_loss: 0.2440 - val_acc: 0.9100 - lr: 0.0010
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1799 - acc: 0.9354
# Epoch 7: val_loss did not improve from 0.24195
# 233/233 [==============================] - 21s 91ms/step - loss: 0.1799 - acc: 0.9354 - val_loss: 0.2426 - val_acc: 0.9128 - lr: 0.0010
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1693 - acc: 0.9376
# Epoch 8: val_loss did not improve from 0.24195
# 233/233 [==============================] - 21s 91ms/step - loss: 0.1693 - acc: 0.9376 - val_loss: 0.2435 - val_acc: 0.9133 - lr: 2.0000e-04
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1675 - acc: 0.9393
# Epoch 9: val_loss did not improve from 0.24195
# 233/233 [==============================] - 21s 92ms/step - loss: 0.1675 - acc: 0.9393 - val_loss: 0.2441 - val_acc: 0.9114 - lr: 2.0000e-04
# Epoch 10/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1666 - acc: 0.9398
# Epoch 10: val_loss did not improve from 0.24195
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1666 - acc: 0.9398 - val_loss: 0.2441 - val_acc: 0.9109 - lr: 4.0000e-05
# 133/133 [==============================] - 3s 15ms/step
# AUC:  0.8808227709310995 AUPRC:  0.5761454695059945 F1:  0.4786324786324786
# 133/133 [==============================] - 2s 15ms/step
# 0.8813578351826674 0.5813835917172963 0.9150898770104068 0.4485407066052227
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2145 - acc: 0.9356
# Epoch 1: val_loss improved from inf to 0.17665, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 23s 90ms/step - loss: 0.2145 - acc: 0.9356 - val_loss: 0.1767 - val_acc: 0.9406 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1720 - acc: 0.9429
# Epoch 2: val_loss improved from 0.17665 to 0.16997, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 21s 88ms/step - loss: 0.1720 - acc: 0.9429 - val_loss: 0.1700 - val_acc: 0.9444 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1554 - acc: 0.9464
# Epoch 3: val_loss did not improve from 0.16997
# 233/233 [==============================] - 22s 92ms/step - loss: 0.1554 - acc: 0.9464 - val_loss: 0.1717 - val_acc: 0.9430 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1456 - acc: 0.9505
# Epoch 4: val_loss did not improve from 0.16997
# 233/233 [==============================] - 22s 95ms/step - loss: 0.1456 - acc: 0.9505 - val_loss: 0.1730 - val_acc: 0.9439 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1342 - acc: 0.9533
# Epoch 5: val_loss did not improve from 0.16997
# 233/233 [==============================] - 22s 97ms/step - loss: 0.1342 - acc: 0.9533 - val_loss: 0.1718 - val_acc: 0.9434 - lr: 2.0000e-04
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1320 - acc: 0.9541
# Epoch 6: val_loss did not improve from 0.16997
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1320 - acc: 0.9541 - val_loss: 0.1715 - val_acc: 0.9444 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1296 - acc: 0.9543
# Epoch 7: val_loss did not improve from 0.16997
# 233/233 [==============================] - 20s 88ms/step - loss: 0.1296 - acc: 0.9543 - val_loss: 0.1714 - val_acc: 0.9444 - lr: 4.0000e-05
# 133/133 [==============================] - 3s 16ms/step
# AUC:  0.8812055673875874 AUPRC:  0.511874463748425 F1:  0.4608695652173913
# 133/133 [==============================] - 2s 17ms/step
# 0.8783542143697527 0.5061142952654252 0.9418164616840113 0.42253521126760557
# Iteration number:  7
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2817 - acc: 0.9047
# Epoch 1: val_loss improved from inf to 0.24772, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 23s 91ms/step - loss: 0.2817 - acc: 0.9047 - val_loss: 0.2477 - val_acc: 0.9147 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2350 - acc: 0.9167
# Epoch 2: val_loss improved from 0.24772 to 0.24413, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 91ms/step - loss: 0.2350 - acc: 0.9167 - val_loss: 0.2441 - val_acc: 0.9128 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2173 - acc: 0.9231
# Epoch 3: val_loss improved from 0.24413 to 0.24172, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 22s 94ms/step - loss: 0.2173 - acc: 0.9231 - val_loss: 0.2417 - val_acc: 0.9114 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2047 - acc: 0.9256
# Epoch 4: val_loss did not improve from 0.24172
# 233/233 [==============================] - 22s 92ms/step - loss: 0.2047 - acc: 0.9256 - val_loss: 0.2436 - val_acc: 0.9100 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1934 - acc: 0.9299
# Epoch 5: val_loss did not improve from 0.24172
# 233/233 [==============================] - 22s 96ms/step - loss: 0.1934 - acc: 0.9299 - val_loss: 0.2434 - val_acc: 0.9114 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1818 - acc: 0.9347
# Epoch 6: val_loss did not improve from 0.24172
# 233/233 [==============================] - 23s 98ms/step - loss: 0.1818 - acc: 0.9347 - val_loss: 0.2446 - val_acc: 0.9128 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1786 - acc: 0.9354
# Epoch 7: val_loss did not improve from 0.24172
# 233/233 [==============================] - 20s 88ms/step - loss: 0.1786 - acc: 0.9354 - val_loss: 0.2457 - val_acc: 0.9100 - lr: 2.0000e-04
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1777 - acc: 0.9352
# Epoch 8: val_loss did not improve from 0.24172
# 233/233 [==============================] - 21s 91ms/step - loss: 0.1777 - acc: 0.9352 - val_loss: 0.2458 - val_acc: 0.9095 - lr: 4.0000e-05
# 133/133 [==============================] - 3s 16ms/step
# AUC:  0.8827092378989226 AUPRC:  0.5811909541701564 F1:  0.48093841642228746
# 133/133 [==============================] - 2s 16ms/step
# 0.8846816660088008 0.5855883984677908 0.9150898770104068 0.48046309696092615
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2118 - acc: 0.9354
# Epoch 1: val_loss improved from inf to 0.18043, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 23s 90ms/step - loss: 0.2118 - acc: 0.9354 - val_loss: 0.1804 - val_acc: 0.9406 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1713 - acc: 0.9431
# Epoch 2: val_loss improved from 0.18043 to 0.17528, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 21s 92ms/step - loss: 0.1713 - acc: 0.9431 - val_loss: 0.1753 - val_acc: 0.9411 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1549 - acc: 0.9468
# Epoch 3: val_loss improved from 0.17528 to 0.17431, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1549 - acc: 0.9468 - val_loss: 0.1743 - val_acc: 0.9411 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1443 - acc: 0.9499
# Epoch 4: val_loss did not improve from 0.17431
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1443 - acc: 0.9499 - val_loss: 0.1752 - val_acc: 0.9425 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1345 - acc: 0.9531
# Epoch 5: val_loss improved from 0.17431 to 0.17378, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 21s 92ms/step - loss: 0.1345 - acc: 0.9531 - val_loss: 0.1738 - val_acc: 0.9416 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1255 - acc: 0.9566
# Epoch 6: val_loss did not improve from 0.17378
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1255 - acc: 0.9566 - val_loss: 0.1801 - val_acc: 0.9420 - lr: 0.0010
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1180 - acc: 0.9593
# Epoch 7: val_loss did not improve from 0.17378
# 233/233 [==============================] - 21s 91ms/step - loss: 0.1180 - acc: 0.9593 - val_loss: 0.1779 - val_acc: 0.9420 - lr: 0.0010
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1099 - acc: 0.9628
# Epoch 8: val_loss did not improve from 0.17378
# 233/233 [==============================] - 21s 92ms/step - loss: 0.1099 - acc: 0.9628 - val_loss: 0.1786 - val_acc: 0.9430 - lr: 2.0000e-04
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1088 - acc: 0.9628
# Epoch 9: val_loss did not improve from 0.17378
# 233/233 [==============================] - 21s 90ms/step - loss: 0.1088 - acc: 0.9628 - val_loss: 0.1791 - val_acc: 0.9420 - lr: 2.0000e-04
# Epoch 10/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1069 - acc: 0.9635
# Epoch 10: val_loss did not improve from 0.17378
# 233/233 [==============================] - 22s 93ms/step - loss: 0.1069 - acc: 0.9635 - val_loss: 0.1793 - val_acc: 0.9416 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 15ms/step
# AUC:  0.8766485686574477 AUPRC:  0.5075542830610451 F1:  0.44635193133047213
# 133/133 [==============================] - 2s 16ms/step
# 0.8783875440368227 0.5061073695825078 0.9396877956480606 0.41647597254004576
# Iteration number:  8
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2847 - acc: 0.9039
# Epoch 1: val_loss improved from inf to 0.25058, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 23s 91ms/step - loss: 0.2847 - acc: 0.9039 - val_loss: 0.2506 - val_acc: 0.9114 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2368 - acc: 0.9164
# Epoch 2: val_loss improved from 0.25058 to 0.24483, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 91ms/step - loss: 0.2368 - acc: 0.9164 - val_loss: 0.2448 - val_acc: 0.9138 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2196 - acc: 0.9215
# Epoch 3: val_loss improved from 0.24483 to 0.24282, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 92ms/step - loss: 0.2196 - acc: 0.9215 - val_loss: 0.2428 - val_acc: 0.9119 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2071 - acc: 0.9256
# Epoch 4: val_loss did not improve from 0.24282
# 233/233 [==============================] - 21s 92ms/step - loss: 0.2071 - acc: 0.9256 - val_loss: 0.2482 - val_acc: 0.9133 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1956 - acc: 0.9282
# Epoch 5: val_loss did not improve from 0.24282
# 233/233 [==============================] - 21s 89ms/step - loss: 0.1956 - acc: 0.9282 - val_loss: 0.2461 - val_acc: 0.9123 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1843 - acc: 0.9324
# Epoch 6: val_loss did not improve from 0.24282
# 233/233 [==============================] - 22s 92ms/step - loss: 0.1843 - acc: 0.9324 - val_loss: 0.2473 - val_acc: 0.9128 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1817 - acc: 0.9343
# Epoch 7: val_loss did not improve from 0.24282
# 233/233 [==============================] - 22s 94ms/step - loss: 0.1817 - acc: 0.9343 - val_loss: 0.2476 - val_acc: 0.9119 - lr: 2.0000e-04
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1794 - acc: 0.9352
# Epoch 8: val_loss did not improve from 0.24282
# 233/233 [==============================] - 21s 92ms/step - loss: 0.1794 - acc: 0.9352 - val_loss: 0.2477 - val_acc: 0.9128 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 15ms/step
# AUC:  0.8794918351534289 AUPRC:  0.5821056579004386 F1:  0.4753363228699552
# 133/133 [==============================] - 2s 16ms/step
# 0.883219741824189 0.5808055738682248 0.9172185430463576 0.46153846153846156
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2135 - acc: 0.9329
# Epoch 1: val_loss improved from inf to 0.18100, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 233/233 [==============================] - 23s 89ms/step - loss: 0.2135 - acc: 0.9329 - val_loss: 0.1810 - val_acc: 0.9406 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1711 - acc: 0.9435
# Epoch 2: val_loss improved from 0.18100 to 0.17170, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# ...
# Epoch 7: val_loss did not improve from 0.24089
# 233/233 [==============================] - 20s 87ms/step - loss: 0.1896 - acc: 0.9323 - val_loss: 0.2411 - val_acc: 0.9142 - lr: 2.0000e-04
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1874 - acc: 0.9314
# Epoch 8: val_loss did not improve from 0.24089
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1874 - acc: 0.9314 - val_loss: 0.2411 - val_acc: 0.9133 - lr: 4.0000e-05
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1880 - acc: 0.9314
# Epoch 9: val_loss did not improve from 0.24089
# 233/233 [==============================] - 20s 86ms/step - loss: 0.1880 - acc: 0.9314 - val_loss: 0.2412 - val_acc: 0.9133 - lr: 4.0000e-05
# Epoch 10/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1869 - acc: 0.9318
# Epoch 10: val_loss did not improve from 0.24089
# 233/233 [==============================] - 20s 86ms/step - loss: 0.1869 - acc: 0.9318 - val_loss: 0.2412 - val_acc: 0.9138 - lr: 1.0000e-05
# 133/133 [==============================] - 2s 14ms/step
# AUC:  0.8828408110755375 AUPRC:  0.5931184479404742 F1:  0.486090775988287
# 133/133 [==============================] - 2s 13ms/step
# 0.8832671081677703 0.5939727868977599 0.9160359508041628 0.48625180897250364
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2193 - acc: 0.9336
# Epoch 1: val_loss improved from inf to 0.17840, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 22s 83ms/step - loss: 0.2193 - acc: 0.9336 - val_loss: 0.1784 - val_acc: 0.9425 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1742 - acc: 0.9432
# Epoch 2: val_loss improved from 0.17840 to 0.17603, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 19s 83ms/step - loss: 0.1742 - acc: 0.9432 - val_loss: 0.1760 - val_acc: 0.9416 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1595 - acc: 0.9467
# Epoch 3: val_loss improved from 0.17603 to 0.17225, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1595 - acc: 0.9467 - val_loss: 0.1723 - val_acc: 0.9425 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1500 - acc: 0.9497
# Epoch 4: val_loss did not improve from 0.17225
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1500 - acc: 0.9497 - val_loss: 0.1732 - val_acc: 0.9434 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1417 - acc: 0.9514
# Epoch 5: val_loss did not improve from 0.17225
# 233/233 [==============================] - 20s 88ms/step - loss: 0.1417 - acc: 0.9514 - val_loss: 0.1739 - val_acc: 0.9369 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1329 - acc: 0.9550
# Epoch 6: val_loss did not improve from 0.17225
# 233/233 [==============================] - 23s 97ms/step - loss: 0.1329 - acc: 0.9550 - val_loss: 0.1729 - val_acc: 0.9392 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1309 - acc: 0.9568
# Epoch 7: val_loss did not improve from 0.17225
# 233/233 [==============================] - 19s 82ms/step - loss: 0.1309 - acc: 0.9568 - val_loss: 0.1732 - val_acc: 0.9406 - lr: 2.0000e-04
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1291 - acc: 0.9560
# Epoch 8: val_loss did not improve from 0.17225
# 233/233 [==============================] - 19s 82ms/step - loss: 0.1291 - acc: 0.9560 - val_loss: 0.1732 - val_acc: 0.9402 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 15ms/step
# AUC:  0.8866599674035857 AUPRC:  0.5243035722810656 F1:  0.4622222222222222
# 133/133 [==============================] - 2s 14ms/step
# 0.8852592881449709 0.5244070532158083 0.9437086092715232 0.4413145539906103
# Iteration number:  9
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2856 - acc: 0.9033
# Epoch 1: val_loss improved from inf to 0.25760, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 22s 85ms/step - loss: 0.2856 - acc: 0.9033 - val_loss: 0.2576 - val_acc: 0.9119 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2396 - acc: 0.9142
# Epoch 2: val_loss improved from 0.25760 to 0.24535, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 19s 83ms/step - loss: 0.2396 - acc: 0.9142 - val_loss: 0.2454 - val_acc: 0.9119 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2223 - acc: 0.9201
# Epoch 3: val_loss did not improve from 0.24535
# 233/233 [==============================] - 20s 85ms/step - loss: 0.2223 - acc: 0.9201 - val_loss: 0.2495 - val_acc: 0.9100 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2106 - acc: 0.9254
# Epoch 4: val_loss improved from 0.24535 to 0.24474, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 20s 87ms/step - loss: 0.2106 - acc: 0.9254 - val_loss: 0.2447 - val_acc: 0.9081 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2023 - acc: 0.9279
# Epoch 5: val_loss improved from 0.24474 to 0.24307, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 21s 89ms/step - loss: 0.2023 - acc: 0.9279 - val_loss: 0.2431 - val_acc: 0.9100 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1936 - acc: 0.9305
# Epoch 6: val_loss improved from 0.24307 to 0.24197, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1936 - acc: 0.9305 - val_loss: 0.2420 - val_acc: 0.9090 - lr: 0.0010
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1862 - acc: 0.9337
# Epoch 7: val_loss did not improve from 0.24197
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1862 - acc: 0.9337 - val_loss: 0.2439 - val_acc: 0.9109 - lr: 0.0010
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1791 - acc: 0.9366
# Epoch 8: val_loss did not improve from 0.24197
# 233/233 [==============================] - 20s 88ms/step - loss: 0.1791 - acc: 0.9366 - val_loss: 0.2455 - val_acc: 0.9062 - lr: 0.0010
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1702 - acc: 0.9397
# Epoch 9: val_loss did not improve from 0.24197
# 233/233 [==============================] - 19s 83ms/step - loss: 0.1702 - acc: 0.9397 - val_loss: 0.2465 - val_acc: 0.9062 - lr: 2.0000e-04
# Epoch 10/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1694 - acc: 0.9392
# Epoch 10: val_loss did not improve from 0.24197
# 233/233 [==============================] - 20s 86ms/step - loss: 0.1694 - acc: 0.9392 - val_loss: 0.2469 - val_acc: 0.9072 - lr: 2.0000e-04
# Epoch 11/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1677 - acc: 0.9398
# Epoch 11: val_loss did not improve from 0.24197
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1677 - acc: 0.9398 - val_loss: 0.2470 - val_acc: 0.9072 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 14ms/step
# AUC:  0.8781901378594505 AUPRC:  0.5763645843708267 F1:  0.4736842105263157
# 133/133 [==============================] - 2s 14ms/step
# 0.8807584462669766 0.5828842277336821 0.9169820245979187 0.48153618906942386
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2181 - acc: 0.9336
# Epoch 1: val_loss improved from inf to 0.18096, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 22s 84ms/step - loss: 0.2181 - acc: 0.9336 - val_loss: 0.1810 - val_acc: 0.9420 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1720 - acc: 0.9426
# Epoch 2: val_loss improved from 0.18096 to 0.17376, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 19s 83ms/step - loss: 0.1720 - acc: 0.9426 - val_loss: 0.1738 - val_acc: 0.9439 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1569 - acc: 0.9461
# Epoch 3: val_loss did not improve from 0.17376
# 233/233 [==============================] - 21s 88ms/step - loss: 0.1569 - acc: 0.9461 - val_loss: 0.1754 - val_acc: 0.9439 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1480 - acc: 0.9494
# Epoch 4: val_loss did not improve from 0.17376
# 233/233 [==============================] - 20s 87ms/step - loss: 0.1480 - acc: 0.9494 - val_loss: 0.1751 - val_acc: 0.9430 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1368 - acc: 0.9524
# Epoch 5: val_loss did not improve from 0.17376
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1368 - acc: 0.9524 - val_loss: 0.1749 - val_acc: 0.9434 - lr: 2.0000e-04
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1348 - acc: 0.9527
# Epoch 6: val_loss did not improve from 0.17376
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1348 - acc: 0.9527 - val_loss: 0.1753 - val_acc: 0.9434 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1331 - acc: 0.9532
# Epoch 7: val_loss did not improve from 0.17376
# 233/233 [==============================] - 19s 83ms/step - loss: 0.1331 - acc: 0.9532 - val_loss: 0.1753 - val_acc: 0.9434 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 14ms/step
# AUC:  0.8782108968013519 AUPRC:  0.5157947465740219 F1:  0.45535714285714285
# 133/133 [==============================] - 2s 14ms/step
# 0.8679378601687147 0.5090476499152261 0.9418164616840113 0.4057971014492754
# Iteration number:  10
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2798 - acc: 0.9051
# Epoch 1: val_loss improved from inf to 0.24787, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 22s 85ms/step - loss: 0.2798 - acc: 0.9051 - val_loss: 0.2479 - val_acc: 0.9123 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2366 - acc: 0.9170
# Epoch 2: val_loss improved from 0.24787 to 0.24109, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 233/233 [==============================] - 20s 84ms/step - loss: 0.2366 - acc: 0.9170 - val_loss: 0.2411 - val_acc: 0.9123 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2197 - acc: 0.9207
# Epoch 3: val_loss did not improve from 0.24109
# 233/233 [==============================] - 20s 85ms/step - loss: 0.2197 - acc: 0.9207 - val_loss: 0.2423 - val_acc: 0.9128 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2063 - acc: 0.9260
# Epoch 4: val_loss did not improve from 0.24109
# 233/233 [==============================] - 19s 84ms/step - loss: 0.2063 - acc: 0.9260 - val_loss: 0.2454 - val_acc: 0.9109 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1940 - acc: 0.9290
# Epoch 5: val_loss did not improve from 0.24109
# 233/233 [==============================] - 20s 87ms/step - loss: 0.1940 - acc: 0.9290 - val_loss: 0.2446 - val_acc: 0.9114 - lr: 2.0000e-04
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1914 - acc: 0.9309
# Epoch 6: val_loss did not improve from 0.24109
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1914 - acc: 0.9309 - val_loss: 0.2445 - val_acc: 0.9133 - lr: 2.0000e-04
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1896 - acc: 0.9315
# Epoch 7: val_loss did not improve from 0.24109
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1896 - acc: 0.9315 - val_loss: 0.2444 - val_acc: 0.9123 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 14ms/step
# AUC:  0.8819899712000936 AUPRC:  0.582363714298122 F1:  0.46246246246246253
# 133/133 [==============================] - 2s 15ms/step
# 0.8808145841556657 0.5784922414297545 0.9146168401135288 0.46038863976083705
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 233/233 [==============================] - ETA: 0s - loss: 0.2191 - acc: 0.9315
# Epoch 1: val_loss improved from inf to 0.18131, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 22s 84ms/step - loss: 0.2191 - acc: 0.9315 - val_loss: 0.1813 - val_acc: 0.9434 - lr: 0.0010
# Epoch 2/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1747 - acc: 0.9429
# Epoch 2: val_loss did not improve from 0.18131
# 233/233 [==============================] - 19s 81ms/step - loss: 0.1747 - acc: 0.9429 - val_loss: 0.1814 - val_acc: 0.9444 - lr: 0.0010
# Epoch 3/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1597 - acc: 0.9454
# Epoch 3: val_loss improved from 0.18131 to 0.17557, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 20s 87ms/step - loss: 0.1597 - acc: 0.9454 - val_loss: 0.1756 - val_acc: 0.9406 - lr: 0.0010
# Epoch 4/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1496 - acc: 0.9492
# Epoch 4: val_loss improved from 0.17557 to 0.17370, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1496 - acc: 0.9492 - val_loss: 0.1737 - val_acc: 0.9434 - lr: 0.0010
# Epoch 5/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1417 - acc: 0.9509
# Epoch 5: val_loss did not improve from 0.17370
# 233/233 [==============================] - 20s 86ms/step - loss: 0.1417 - acc: 0.9509 - val_loss: 0.1753 - val_acc: 0.9425 - lr: 0.0010
# Epoch 6/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1343 - acc: 0.9522
# Epoch 6: val_loss did not improve from 0.17370
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1343 - acc: 0.9522 - val_loss: 0.1753 - val_acc: 0.9444 - lr: 0.0010
# Epoch 7/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1256 - acc: 0.9565
# Epoch 7: val_loss did not improve from 0.17370
# 233/233 [==============================] - 20s 84ms/step - loss: 0.1256 - acc: 0.9565 - val_loss: 0.1762 - val_acc: 0.9434 - lr: 2.0000e-04
# Epoch 8/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1240 - acc: 0.9568
# Epoch 8: val_loss did not improve from 0.17370
# 233/233 [==============================] - 20s 85ms/step - loss: 0.1240 - acc: 0.9568 - val_loss: 0.1772 - val_acc: 0.9425 - lr: 2.0000e-04
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 0.1221 - acc: 0.9579
# Epoch 9: val_loss did not improve from 0.17370
# 233/233 [==============================] - 20s 88ms/step - loss: 0.1221 - acc: 0.9579 - val_loss: 0.1773 - val_acc: 0.9425 - lr: 4.0000e-05
# 133/133 [==============================] - 2s 15ms/step
# AUC:  0.8802540053927401 AUPRC:  0.5196339417018773 F1:  0.4563758389261745
# 133/133 [==============================] - 2s 15ms/step
# 0.8821379648238695 0.5262366487738962 0.9439451277199622 0.44755244755244755
